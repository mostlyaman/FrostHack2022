# %%
import pandas as pd

df = pd.read_csv("Teams - Form Responses 1.csv")

# %%
df
# Out:
#              Timestamp                   Email Address                 Name  \
# 0   2/23/2022 15:02:11  b20126@students.iitmandi.ac.in           Rijul Jain
# 1   2/23/2022 20:06:00  b19107@students.iitmandi.ac.in         Rishabh Garg
# 2   2/23/2022 20:31:16  b20294@students.iitmandi.ac.in        Kishan Sharma
# 3   2/23/2022 21:49:52  b20103@students.iitmandi.ac.in        Dipesh Sharma
# 4   2/23/2022 16:03:08  b19100@students.iitmandi.ac.in               Paras
# 5   2/23/2022 14:35:24  b19222@students.iitmandi.ac.in       Shubham Saurav
# 6   2/23/2022 14:38:19  b19144@students.iitmandi.ac.in           Yash Verma
# 7   2/23/2022 21:06:28  b20183@students.iitmandi.ac.in        Anurag Maurya
# 8   2/23/2022 15:38:28  b20087@students.iitmandi.ac.in      Ashutosh Sharma
# 9   2/23/2022 14:45:17  b20112@students.iitmandi.ac.in         Kuldeep Jain
# 10  2/23/2022 14:46:53  b20113@students.iitmandi.ac.in     Lavish Sachdeva
# ...

# %%
records = df.to_records(index=False)
for member in records:
    print("<Member name=\"",member[2],"\" phone=\"",str(int(member[5])),"\" role=\"",member[3],"\" fb=\"",member[4],"\"/>",sep='')
# Out:
# <Member name="Rijul Jain" phone="9910844346" role="Technical Head" fb="https://www.facebook.com/rijul.jain.144/"/>
# <Member name="Rishabh Garg" phone="7027760333" role="Technical Head" fb="https://www.facebook.com/profile.php?id=100039774819697"/>
# <Member name="Kishan Sharma" phone="8000543233" role="Technical" fb="https://www.facebook.com/kishan.raneja.borwa"/>
# <Member name="Dipesh Sharma" phone="7339821343" role="Technical" fb="www.facebook.com"/>
# <Member name="Paras " phone="7860688567" role="Sponsor Head" fb="https://www.facebook.com/profile.php?id=100008742852432"/>
# <Member name="Shubham Saurav" phone="9304902560" role="Sponsor Head" fb="https://www.facebook.com/shubham.saurav.980967"/>
# <Member name="Yash Verma" phone="9818722716" role="Sponsor Head" fb="https://www.facebook.com/uchihamangekyoun/"/>
# <Member name="Anurag Maurya" phone="7379906268" role="Sponsor" fb="https://www.facebook.com"/>
# ...
